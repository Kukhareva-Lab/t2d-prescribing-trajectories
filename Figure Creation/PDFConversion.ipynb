# %%
# !ls /content

# %%
# !apt-get update
# !apt-get install -y poppler-utils

# %%
# !pdftoppm -r 600 -tiff -rgb "/content/Monotherapy_Group.pdf" "/content/Monotherapy_Group.tif"

# %%
# !pdfinfo "/content/Monotherapy_Group.pdf"

# %%
# !mkdir -p "/content/tiffs"
# !pdftoppm -r 600 -tiff -singlefile "/content/Monotherapy_Group.pdf" "/content/tiffs/test"
# !ls -lah "/content/tiffs"

# %%
# !ls -lah /content/tiffs
